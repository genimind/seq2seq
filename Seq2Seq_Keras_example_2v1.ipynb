# %% [markdown]
# # Example-2 based on Keras tutorial on Seq2Seq [blog](https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html).
#
# [dataset source (english-french)](http://www.manythings.org/anki/fra-eng.zip)
#
# In this example we'll use words as tokens and LSTM

# %% [markdown]
# ### data prep

# %%
import numpy as np
from keras.preprocessing.text import text_to_word_sequence
from keras.models import Model
from keras.layers import Input, LSTM, Dense
from keras.layers.embeddings import Embedding
from keras.losses import sparse_categorical_crossentropy
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
def sequence_to_text(sequence, tokenizer):
    index_to_words = {id: word for word, id in tokenizer.word_index.items()}
    return ' '.join([index_to_words[token] for token in sequence if token > 0])

# %%
filename = 'fra.txt'
input_texts_seq = []
target_texts_seq = []
lines = open(filename).read().split('\n')
num_samples = 10000
special_words = ['<PAD>', '<UNK>', '<GO>',  '<EOS>']

input_words = set(special_words)
target_words = set(special_words)

# process the lines
for line in lines[:min(num_samples, len(lines)-1)]:
    input_text, target_text = line.split('\t')
    # delimiter target_text with '<start>' for start word and '<end>' for end word
    input_text_seq = text_to_word_sequence(input_text)
    target_text_seq = text_to_word_sequence(target_text)
    target_text_seq = ['<GO>'] + target_text_seq + ['<EOS>']
    
    input_texts_seq.append(input_text_seq)
    target_texts_seq.append(target_text_seq)
    
    for w in input_text_seq:
        if w not in input_words:
            input_words.add(w)
    
    for w in target_text_seq:
        if w not in target_words:
            target_words.add(w)

input_words = sorted(list(input_words))
target_words = sorted(list(target_words))

num_encoder_tokens = len(input_words)
num_decoder_tokens = len(target_words)
max_encoder_seq_length = max([len(seq) for seq in input_texts_seq])
max_decoder_seq_length = max([len(seq) for seq in target_texts_seq])
num_samples = len(input_texts_seq)

print ('number of samples: ', num_samples)
print ('number of input  tokens:', num_encoder_tokens)
print ('number of output tokens:', num_decoder_tokens)
print ('Max sequence length for inputs:', max_encoder_seq_length)
print ('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# number of samples:  10000
# number of input  tokens: 2226
# number of output tokens: 4578
# Max sequence length for inputs: 5
# Max sequence length for outputs: 12

# %%
print(target_texts_seq[10])
# Out:
# ['<GO>', 'attends', '<EOS>']

# %%
input_token_index  = dict([(w, i) for i, w in enumerate(input_words)])
input_index_token  = dict([(i, w) for i, w in enumerate(input_words)])
target_token_index = dict([(w, i) for i, w in enumerate(target_words)])
target_index_token = dict([(i, w) for i, w in enumerate(target_words)])

# %%
print(target_token_index)
# Out:
# {'problème\u202f': 3220, 'd’autre\u202f': 1322, 'enceinte': 1366, 'anxieux': 181, 'augmentation': 312, 'flipe': 1607, 'jour': 2117, 'contrôler': 837, 'accompagner\u202f': 29, 'affreusement': 72, 'piégé': 3062, 'fauchés': 1533, 'dort': 1159, 'horrifiée': 1871, 'ressens': 3521, 'vu\u202f': 4441, 'pleine': 3105, 'entretenues': 1415, 'moins': 2607, 'firefox': 1588, 'parties': 2935, "l'appela": 2177, 'coupai': 872, 'espèce': 1443, 'gérerai': 1815, 'avise': 345, 'attachez': 275, 'embrassé': 1346, 'ville': 4364, 'abandonnez': 12, 'causer': 569, 'honnête': 1859, 'blessée\u202f': 431, 'méditer': 2681, 'honorée': 1862, '6': 4, 'tenter': 4084, 'meurs': 2568, 'opération': 2856, 'videz': 4346, 'prévenue': 3282, 'osez': 2865, 'excité': 1472, 'foutre': 1647, 'biscuits': 415, 'amoureux': 154, 'recrutés': 3418, 'sérieuse': 3994, "jusqu'ici": 2134, 'loyale': 2346, 'commère': 745, 'fixa': 1591, 'marié\u202f': 2493, 'décéda': 1220, 'attaqué': 280, 'question': 3351, 'créatif': 939, 'football': 1625, 'pari': 2912, 'pige': 3042, 'marrant': 2495, 'pratiquez': 3188, 'grouiller': 1796, 'renvoyé': 3497, 'fantômes': 1521, 'astucieuse': 272, 'flics': 1606, 'donnez': 1149, "m'ont": 2409, 'désarmé': 1277, 'appelé': 195, 'noie': 2773, 'pièces': 3060, 'pleut': 3115, 'crie': 918, 'fous': 1645, 'magne': 2418, 'manges': 2462, 'chauves': 646, 'gourmand': 1749, 'ennuis': 1390, 'dément': 1248, 'regardes': 3441, "qu'en": 3327, "n'étais": 2733, 'place\u2009': 3068, 'manquez': 2478, 'lignes': 2320, 'déshabille': 1283, 'asseyez': 257, 'dois': 1138, 'remplace': 3464, 'échoué': 4480, "jusqu'à": 2135, 'amusez': 158, 'cœur': 972, 'étendu': 4545, 'cuis': 948, 'sortons': 3869, 'remariée': 3451, 'partiale': 2933, 'montres': 2620, 'mouillée': 2649, 'fille': 1576, 'équitable': 4536, "t'inquiète": 4040, 'berné': 400, 'ailles': 95, 'conduirai': 769, 'doit': 1139, '100': 1, 'endormie': 1372, 'soucier': 3874, 'veinarde': 4306, 'étranger': 4553, 'plaisantes\u202f': 3081, 'brillants': 492, 'véhicule': 4443, 'chose': 680, 'dirai': 1091, 'mouillé': 2648, 'ponctuel': 3136, 'pressons': 3199, 'biaisé': 403, 'tua': 4248, "t'attends": 4026, 'marrés': 2504, 'paix\u202f': 2889, 'thune': 4101, 'comprends': 753, 'chocolat': 671, 'construit\u202f': 809, 'fruits': 1670, 'ficherais': 1564, 'entrer\u202f': 1414, 'augmente': 313, 'consciencieuse': 801, 'était': 4540, 'désir': 1286, 'dormir': 1154, 'aiment': 100, 'tenterai': 4085, 'naïfs': 2750, 'désobéi': 1288, 'débarqué': 1195, 'bigot': 412, 'avis': 344, 'imprudents': 1937, 'ruiné': 3597, 'bois': 439, 'elle': 1333, 'fut': 1683, 'sonne': 3854, 'trouver': 4232, 'comment': 740, 'assuré': 268, 'connais': 787, 'enterrée': 1407, 'veuillez': 4336, 'crois': 924, 'haïssaient': 1839, 'avalé': 329, 'synchronisées': 3983, 'allongé': 123, 'demie': 1044, 'chouettes': 684, "t'inviterai": 4042, 'ai': 85, 'service': 3792, 'dressai': 1175, 'cléments': 707, 'mettre': 2566, 'sans': 3703, 'seuls': 3800, 'droit': 1181, 'morflé': 2632, 'épidémie': 4525, 'laisse': 2267, "qu'y": 3332, '<PAD>': 7, 'haricots': 1833, 'rembourser': 3455, 'blessé\u202f': 434, 'approchez': 210, 'attrapés': 306, 'trente': 4208, 'reposer': 3503, 'agir': 78, 'achetons': 38, "t'entendre": 4035, 'problème': 3219, 'analphabète': 167, 'silence': 3818, 'masochiste': 2507, 'créatives': 942, 'cesser': 589, 'raser': 3391, 'essaies': 1445, 'tournait': 4162, 'dessine': 1055, "t'échauffer": 4044, "qu'il": 3329, 'attraper': 301, 'esseulée\u202f': 1454, 'dures': 1190, 'revenez': 3547, 'grossière': 1793, 'aimé': 106, 'impuissants': 1939, 'sait': 3694, 'connaissais': 788, 'durs': 1191, 'dupa': 1187, 'souvenez\u202f': 3911, 'marré': 2501, 'cinq': 688, "l'attraperai": 2193, 'tel': 4073, 'évident': 4572, 'possède': 3156, 'diriez': 1098, 'lasses': 2289, 'suivez': 3950, 'arrêtions': 249, 'tort\u202f': 4145, 'témoignerai': 4267, 'reconnaissants': 3411, 'né': 2811, "t'es": 4038, 'œil': 4576, 'chiens': 664, 'rhume': 3559, 'commença': 743, 'vidéo': 4347, 'pensionné': 2993, 'devenu': 1063, 'suffit\u202f': 3943, 'tirez': 41 ...

# %%
# initialization of the tensors used for training
encoder_input_data  = np.zeros((num_samples, max_encoder_seq_length, num_encoder_tokens), dtype='float32')
decoder_input_data  = np.zeros((num_samples, max_decoder_seq_length, num_decoder_tokens), dtype='float32')
decoder_target_data = np.zeros((num_samples, max_decoder_seq_length, num_decoder_tokens), dtype='float32')

# %%
# setup the tensors from the input data for the model
for i, (input_text_seq, target_text_seq) in enumerate(zip(input_texts_seq, target_texts_seq)):
    for j, w in enumerate(input_text_seq):
        encoder_input_data[i, j, input_token_index[w]] = 1
    for j, w in enumerate(target_text_seq):
        # decoder_input_data is ahead of decoder_target_data by one timestep
        decoder_input_data[i, j, target_token_index[w]] = 1
        if j > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start token <GO>.
            decoder_target_data[i, j - 1, target_token_index[w]] = 1

# %%
# model setup using LSTM

latent_dim = 128  # Latent dimensionality of the encoding space.

# encoder
encoder_input = Input(shape=(None, num_encoder_tokens))
# embedded_encoder = Embedding(input_dim=num_encoder_tokens, 
#                              input_length=max_encoder_seq_length, output_dim=256)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True, name='encoder_lstm')
encoder_outputs, state_h, state_c = encoder_lstm(encoder_input)
# we'll only use the encoder state
encoder_states = [state_h, state_c]

# decoder
decoder_input = Input(shape=(None, num_decoder_tokens))
# embedded_decoder = Embedding(input_dim=num_decoder_tokens, 
#                              input_length=max_decoder_seq_length, output_dim=256)(decoder_inputs)
# decoder will return full output sequence and internal states
# internal states will be used during inference and not during training.
decoder_lstm = LSTM(latent_dim, return_state=True, return_sequences=True, name='decoder_lstm')
# Set up the decoder, using `encoder_states` as initial state.
decoder_output, _, _ = decoder_lstm(decoder_input, initial_state=encoder_states)

# decoder_output = Dense(256, activation='relu', name='decoder_dense1')(decoder_outputs)
# decoder_output = Dense(num_decoder_tokens, activation='softmax', name='decoder_dense2')(decoder_output)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_output = decoder_dense(decoder_output)


model = Model([encoder_input, decoder_input], decoder_output)

# %%
import json
model.summary()
# print(encoder_input_data.shape)
# print(encoder_input_data.shape[-1])
# model_as_json = json.loads(model.to_json())
# print(json.dumps(model_as_json, indent=2))
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_3 (InputLayer)             (None, None, 2226)    0
# ____________________________________________________________________________________________________
# input_4 (InputLayer)             (None, None, 4578)    0
# ____________________________________________________________________________________________________
# encoder_lstm (LSTM)              [(None, 128), (None,  1205760     input_3[0][0]
# ____________________________________________________________________________________________________
# decoder_lstm (LSTM)              [(None, None, 128), ( 2409984     input_4[0][0]
#                                                                    encoder_lstm[0][1]
#                                                                    encoder_lstm[0][2]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, None, 4578)    590562      decoder_lstm[0][0]
# ====================================================================================================
# Total params: 4,206,306
# Trainable params: 4,206,306
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint

# Run training

batch_size = 200  # Batch size for training.
epochs = 10  # Number of epochs to train for.
# learning_rate = 0.005

checkpointer = ModelCheckpoint(filepath='seq2seq_weights_best_2.hdf5', 
                           verbose=1, save_best_only=True)

model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
                  metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
         batch_size=batch_size, epochs=epochs, validation_split=0.2, callbacks=[checkpointer])
# save the model
model.save('seq2seq_2.h5')
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/20
# Epoch 00000: val_loss improved from inf to 2.27266, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 87s - loss: 2.2191 - acc: 0.0816 - val_loss: 2.2727 - val_acc: 0.0934
# Epoch 2/20
# Epoch 00001: val_loss improved from 2.27266 to 2.25175, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 86s - loss: 1.8441 - acc: 0.1020 - val_loss: 2.2517 - val_acc: 0.1066
# Epoch 3/20
# Epoch 00002: val_loss improved from 2.25175 to 2.22262, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 86s - loss: 1.7774 - acc: 0.1029 - val_loss: 2.2226 - val_acc: 0.1108
# Epoch 4/20
# Epoch 00003: val_loss did not improve
# 8000/8000 [==============================] - 90s - loss: 1.7172 - acc: 0.1086 - val_loss: 2.2228 - val_acc: 0.1117
# Epoch 5/20
# Epoch 00004: val_loss improved from 2.22262 to 2.22248, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 97s - loss: 1.6752 - acc: 0.1099 - val_loss: 2.2225 - val_acc: 0.1128
# Epoch 6/20
# Epoch 00005: val_loss improved from 2.22248 to 2.20274, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 95s - loss: 1.6366 - acc: 0.1143 - val_loss: 2.2027 - val_acc: 0.1160
# Epoch 7/20
# Epoch 00006: val_loss improved from 2.20274 to 2.19101, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 94s - loss: 1.6004 - acc: 0.1180 - val_loss: 2.1910 - val_acc: 0.1187
# Epoch 8/20
# Epoch 00007: val_loss improved from 2.19101 to 2.16302, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 95s - loss: 1.5666 - acc: 0.1198 - val_loss: 2.1630 - val_acc: 0.1214
# Epoch 9/20
# Epoch 00008: val_loss improved from 2.16302 to 2.13575, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 95s - loss: 1.5325 - acc: 0.1214 - val_loss: 2.1357 - val_acc: 0.1238
# Epoch 10/20
# Epoch 00009: val_loss improved from 2.13575 to 2.12968, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 96s - loss: 1.4990 - acc: 0.1243 - val_loss: 2.1297 - val_acc: 0.1228
# Epoch 11/20
# Epoch 00010: val_loss improved from 2.12968 to 2.09502, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 96s - loss: 1.4670 - acc: 0.1266 - val_loss: 2.0950 - val_acc: 0.1277
# Epoch 12/20
# Epoch 00011: val_loss improved from 2.09502 to 2.07838, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 96s - loss: 1.4347 - acc: 0.1295 - val_loss: 2.0784 - val_acc: 0.1297
# Epoch 13/20
# Epoch 00012: val_loss improved from 2.07838 to 2.05793, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 97s - loss: 1.4002 - acc: 0.1334 - val_loss: 2.0579 - val_acc: 0.1370
# Epoch 14/20
# Epoch 00013: val_loss improved from 2.05793 to 2.02635, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 96s - loss: 1.3646 - acc: 0.1372 - val_loss: 2.0264 - val_acc: 0.1394
# Epoch 15/20
# Epoch 00014: val_loss did not improve
# 8000/8000 [==============================] - 95s - loss: 1.3252 - acc: 0.1418 - val_loss: 2.0271 - val_acc: 0.1413
# Epoch 16/20
# Epoch 00015: val_loss improved from 2.02635 to 1.95901, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 95s - loss: 1.2843 - acc: 0.1474 - val_loss: 1.9590 - val_acc: 0.1516
# Epoch 17/20
# Epoch 00016: val_loss improved from 1.95901 to 1.95638, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 95s - loss: 1.2422 - acc: 0.1528 - val_loss: 1.9564 - val_acc: 0.1558
# Epoch 18/20
# Epoch 00017: val_loss improved from 1.95638 to 1.90217, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 95s - loss: 1.2022 - acc: 0.1585 - val_loss: 1.9022 - val_acc: 0.1623
# Epoch 19/20
# Epoch 00018: val_loss improved from 1.90217 to 1.87966, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 95s - loss: 1.1658 - acc: 0.1648 - val_loss: 1.8797 - val_acc: 0.1653
# Epoch 20/20
# Epoch 00019: val_loss improved from 1.87966 to 1.86175, saving model to seq2seq_weights_best_2.hdf5
# 8000/8000 [==============================] - 96s - loss: 1.1288 - acc: 0.1697 - val_loss: 1.8618 - val_acc: 0.1696

# %%
from keras.models import load_model

# del model
model = load_model('seq2seq_2.h5')

model.layers

# %%
# Inference... testing the model
# Here's the drill from the Keras tutorial code:
# 1) encode input and retrieve initial decoder state
# 2) run one step of decoder with this initial state
#    and a "start of sequence" token as target.
#    Output will be the next target token
# 3) Repeat with the current target token and current states

from keras.models import load_model

# model = load_model('seq2seq_2.h5')

# inference models
encoder_model = Model(encoder_input, encoder_states)
# encoder_model.summary()

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_state_inputs = [decoder_state_input_h, decoder_state_input_c]
# decoder_inputs = Input(shape=(None,))
# embedded_decoder = Embedding(num_decoder_tokens, latent_dim)(decoder_inputs)
# decoder_lstm = LSTM(latent_dim, return_state=True, return_sequences=True)

decoder_output, state_h, state_c = decoder_lstm(decoder_input, initial_state=decoder_state_inputs)
decoder_states = [state_h, state_c]

# decoder_output = Dense(256, activation='relu', name='decoder_dense1')(decoder_output)
# decoder_output = Dense(num_decoder_tokens, activation='softmax', name='decoder_dense2')(decoder_output)
decoder_output = decoder_dense(decoder_output)

decoder_model = Model([decoder_input]+decoder_state_inputs, [decoder_output]+decoder_states)

# save the model
decoder_model.save('seq2seq_inference_2.h5')

# %%
# model.summary()
# encoder_model.summary()
decoder_model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_4 (InputLayer)             (None, None, 4578)    0
# ____________________________________________________________________________________________________
# input_5 (InputLayer)             (None, 128)           0
# ____________________________________________________________________________________________________
# input_6 (InputLayer)             (None, 128)           0
# ____________________________________________________________________________________________________
# decoder_lstm (LSTM)              [(None, None, 128), ( 2409984     input_4[0][0]
#                                                                    input_5[0][0]
#                                                                    input_6[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, None, 4578)    590562      decoder_lstm[1][0]
# ====================================================================================================
# Total params: 3,000,546
# Trainable params: 3,000,546
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
def decode_sequence(input_seq):
    # get encoded state vectors from input
    states = encoder_model.predict(input_seq)
    # define empty target sequence of length 1
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # set the first token of target sequence with the start token
    target_seq[0, 0, target_token_index['<GO>']] = 1
    
    # loop on the batch of sequences
    done = False
    decoded_sequence = []
    while not done:
        output_tokens, h, c = decoder_model.predict([target_seq]+states)
        decoded_token_index = np.argmax(output_tokens[0, -1, :])
        decoded_token = target_index_token[decoded_token_index]
        decoded_sequence.append(decoded_token)
        # we are done if we hit stop token or the sequence is at max length
        if (decoded_token == '<EOS>' or 
           len(decoded_sequence) > max_decoder_seq_length):
            done = True
            
        # update the target sequence of length 1
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, decoded_token_index] = 1
        # update states
        states = [h, c]
    
    return decoded_sequence

# %%
# testing
for seq_index in range(10):
    input_seq = encoder_input_data[seq_index: seq_index+1]
    decoded_sequence = decode_sequence(input_seq)
    print('++--------------++')
    print('input seq  : ', input_texts_seq[seq_index])
    #print('dseq: ', decoded_sequence)
    #print('decoded seq: ', logits_to_text(decoded_sequence[0], target_texts_tokenizer))
    print('decoded seq: ', decoded_sequence)
# Out:
# ++--------------++
# input seq  :  ['go']
# decoded seq:  ['arrête', 'de', 'de', 'de', 'maison', '<EOS>']
# ++--------------++
# input seq  :  ['run']
# decoded seq:  ['arrête', '<EOS>']
# ++--------------++
# input seq  :  ['run']
# decoded seq:  ['arrête', '<EOS>']
# ++--------------++
# input seq  :  ['wow']
# decoded seq:  ["c'est", 'un', '<EOS>']
# ++--------------++
# input seq  :  ['fire']
# decoded seq:  ['arrête', 'de', 'de', 'de', 'de', 'maison', '<EOS>']
# ++--------------++
# input seq  :  ['help']
# decoded seq:  ['arrête', '<EOS>']
# ++--------------++
# input seq  :  ['jump']
# decoded seq:  ['arrête', 'de', 'de', 'de', 'de', 'maison', '<EOS>']
# ++--------------++
# input seq  :  ['stop']
# decoded seq:  ['arrête', 'de', 'de', 'de', 'de', 'maison', '<EOS>']
# ++--------------++
# input seq  :  ['stop']
# decoded seq:  ['arrête', 'de', 'de', 'de', 'de', 'maison', '<EOS>']
# ++--------------++
# input seq  :  ['stop']
# decoded seq:  ['arrête', 'de', 'de', 'de', 'de', 'maison', '<EOS>']
